# %%
# %pip install ultralytics

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.99 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.2/112.6 GB disk)

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("msambare/fer2013")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 60.3M/60.3M [00:00<00:00, 132MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/msambare/fer2013/versions/1

# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n-cls.pt')
# Out:
# ...
# 100%|██████████| 5.31M/5.31M [00:00<00:00, 93.8MB/s]

# %%
model.train(data='/root/.cache/kagglehub/datasets/msambare/fer2013/versions/1', epochs=10)
# Out:
# Ultralytics 8.3.99 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
model.save('FER.pt')

# %%
model = YOLO("FER.pt")

# %%
results = model(["/content/kizgin.png"])
# Out:
# 0: 224x224 angry 0.52, sad 0.16, fear 0.15, neutral 0.09, happy 0.05, 4.9ms
# Speed: 6.0ms preprocess, 4.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)

# %%
results = model.predict("/content/kizgin.png", save=True, imgsz=320, conf=0.5, project="/content")
# Out:
# image 1/1 /content/üzgün.png: 224x224 angry 0.52, sad 0.16, fear 0.15, neutral 0.09, happy 0.05, 14.5ms
# Speed: 34.5ms preprocess, 14.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to /content/predict2

# %%
import cv2

# %%
kizgin = cv2.imread("/content/predict/üzgün.jpg")
kizgin = cv2.cvtColor(kizgin, cv2.COLOR_BGR2RGB)

# %%
kizgin
# Out:
# array([[[237, 243, 243],
#         [237, 243, 243],
#         [238, 244, 244],
#         ...,
#         [238, 242, 243],
#         [238, 242, 243],
#         [238, 242, 243]],
#
#        [[237, 243, 243],
#         [238, 244, 244],
#         [238, 244, 244],
#         ...,
#         [238, 242, 243],
#         [238, 242, 243],
#         [238, 242, 243]],
#
#        [[237, 243, 243],
#         [238, 244, 244],
#         [239, 243, 244],
#         ...,
#         [238, 242, 243],
#         [238, 242, 243],
#         [238, 242, 243]],
#
#        ...,
#
#        [[246, 247, 249],
#         [246, 247, 249],
#         [246, 247, 249],
#         ...,
#         [251, 255, 255],
#         [250, 251, 253],
#         [253, 251, 252]],
#
#        [[246, 247, 249],
#         [246, 247, 249],
#         [246, 247, 249],
#         ...,
#         [251, 255, 255],
#         [254, 255, 255],
#         [255, 254, 255]],
#
#        [[246, 247, 249],
#         [246, 247, 249],
#         [246, 247, 249],
# ...

# %%
print(results)
# Out:
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: None
# keypoints: None
# masks: None
# names: {0: 'angry', 1: 'disgust', 2: 'fear', 3: 'happy', 4: 'neutral', 5: 'sad', 6: 'surprise'}
# obb: None
# orig_img: array([[[243, 242, 238],
#         [244, 243, 239],
#         [244, 243, 239],
#         ...,
#         [243, 242, 238],
#         [243, 242, 238],
#         [243, 242, 238]],
#
#        [[243, 242, 238],
#         [244, 243, 239],
#         [244, 243, 239],
#         ...,
#         [243, 242, 238],
#         [243, 242, 238],
#         [243, 242, 238]],
#
#        [[243, 242, 238],
#         [244, 243, 239],
#         [244, 243, 239],
#         ...,
#         [243, 242, 238],
#         [243, 242, 238],
#         [243, 242, 238]],
#
#        ...,
#
#        [[249, 247, 246],
#         [249, 247, 246],
#         [249, 247, 246],
#         ...,
#         [253, 253, 255],
#         [253, 253, 253],
#         [253, 253, 253]],
#
#        [[249, 247, 246],
# ...

# %%
results[0].probs.top1
# Out:
# 0

# %%
results[0].probs.top5
# Out:
# [0, 5, 2, 4, 3]
